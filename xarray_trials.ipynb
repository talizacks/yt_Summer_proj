# %%
import xarray as xr
import pygrib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import yt
import ipywidgets

# %% [markdown]
#     filter_by_keys={'typeOfLevel': 'heightAboveGround'}
#     filter_by_keys={'typeOfLevel': 'isobaricInhPa'}
#     filter_by_keys={'typeOfLevel': 'meanSea'}
#     filter_by_keys={'typeOfLevel': 'surface'}
#     filter_by_keys={'typeOfLevel': 'pressureFromGroundLayer'}
#     filter_by_keys={'typeOfLevel': 'sigmaLayer'}
#     filter_by_keys={'typeOfLevel': 'isothermZero'}
#     filter_by_keys={'typeOfLevel': 'heightAboveGroundLayer'}
#     filter_by_keys={'typeOfLevel': 'tropopause'}
#     filter_by_keys={'typeOfLevel': 'atmosphereSingleLayer'}
#     filter_by_keys={'typeOfLevel': 'isobaricLayer'}
#     filter_by_keys={'typeOfLevel': 'maxWind'}
#     filter_by_keys={'typeOfLevel': 'hybrid'}

# %%
hag = xr.load_dataset('Boulder_Fire_Event/Model_Output/CONUS_12km_20090107_1200.grib2', engine='cfgrib', filter_by_keys={'typeOfLevel': 'heightAboveGround'})
isobaric = xr.load_dataset('Boulder_Fire_Event/Model_Output/CONUS_12km_20090107_1200.grib2', engine='cfgrib', filter_by_keys={'typeOfLevel': 'heightAboveGround'})
meanSea = xr.load_dataset('Boulder_Fire_Event/Model_Output/CONUS_12km_20090107_1200.grib2', engine='cfgrib', filter_by_keys={'typeOfLevel': 'meanSea'})
surface = xr.load_dataset('Boulder_Fire_Event/Model_Output/CONUS_12km_20090107_1200.grib2', engine='cfgrib', filter_by_keys={'typeOfLevel': 'surface'})
pressGL = xr.load_dataset('Boulder_Fire_Event/Model_Output/CONUS_12km_20090107_1200.grib2', engine='cfgrib', filter_by_keys={'typeOfLevel': 'pressureFromGroundLayer'})
sigma = xr.load_dataset('Boulder_Fire_Event/Model_Output/CONUS_12km_20090107_1200.grib2', engine='cfgrib', filter_by_keys={'typeOfLevel': 'sigmaLayer'})
isotherm = xr.load_dataset('Boulder_Fire_Event/Model_Output/CONUS_12km_20090107_1200.grib2', engine='cfgrib', filter_by_keys={'typeOfLevel': 'isothermZero'})
tropopause = xr.load_dataset('Boulder_Fire_Event/Model_Output/CONUS_12km_20090107_1200.grib2', engine='cfgrib', filter_by_keys={'typeOfLevel': 'tropopause'})
atmos = xr.load_dataset('Boulder_Fire_Event/Model_Output/CONUS_12km_20090107_1200.grib2', engine='cfgrib', filter_by_keys={'typeOfLevel': 'atmosphereSingleLayer'})
maxWind = xr.load_dataset('Boulder_Fire_Event/Model_Output/CONUS_12km_20090107_1200.grib2', engine='cfgrib', filter_by_keys={'typeOfLevel': 'maxWind'})
# Out:
# skipping variable: paramId==166 shortName='v10'
# Traceback (most recent call last):
#   File "/Users/tzacks2/.conda/envs/DataViz/lib/python3.7/site-packages/cfgrib/dataset.py", line 660, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "/Users/tzacks2/.conda/envs/DataViz/lib/python3.7/site-packages/cfgrib/dataset.py", line 593, in dict_merge
#     "key=%r value=%r new_value=%r" % (key, master[key], value)
# cfgrib.dataset.DatasetBuildError: key present and new value is different: key='heightAboveGround' value=Variable(dimensions=(), data=2.0) new_value=Variable(dimensions=(), data=10.0)
# skipping variable: paramId==165 shortName='u10'
# Traceback (most recent call last):
#   File "/Users/tzacks2/.conda/envs/DataViz/lib/python3.7/site-packages/cfgrib/dataset.py", line 660, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "/Users/tzacks2/.conda/envs/DataViz/lib/python3.7/site-packages/cfgrib/dataset.py", line 593, in dict_merge
# ...

# %%
hag
# Out:
# <xarray.Dataset>
# Dimensions:            (step: 29, y: 428, x: 614)
# Coordinates:
#     time               datetime64[ns] 2009-01-07T12:00:00
#   * step               (step) timedelta64[ns] 0 days 00:00:00 ... 3 days 12:0...
#     heightAboveGround  float64 2.0
#     latitude           (y, x) float64 12.19 12.22 12.25 ... 57.39 57.36 57.33
#     longitude          (y, x) float64 226.5 226.6 226.8 ... 310.3 310.4 310.6
#     valid_time         (step) datetime64[ns] 2009-01-07T12:00:00 ... 2009-01-11
# Dimensions without coordinates: y, x
# Data variables:
#     r2                 (step, y, x) float32 84.0 84.0 85.0 ... 90.0 89.0 88.0
#     t2m                (step, y, x) float32 297.4 297.5 297.4 ... 272.6 272.7
#     d2m                (step, y, x) float32 294.5 294.5 294.7 ... 271.1 271.0
#     tmin               (step, y, x) float32 297.4 297.4 297.4 ... 272.7 272.8
#     tmax               (step, y, x) float32 297.4 297.4 297.4 ... 272.8 272.9
# Attributes:
# ...

# %%
for i in hag.data_vars:
    print(i)
# Out:
# r2
# t2m
# d2m
# tmin
# tmax

# %% [markdown]
# 'hag','isobaric','meanSea','surface','pressGL','sigma','isotherm','tropopause','atmos','maxWind'
# hag,isobaric,meanSea,surface,pressGL,sigma,isotherm,tropopause,atmos,maxWind

# %%
layers = [hag,isobaric,meanSea,surface,pressGL,sigma,isotherm,tropopause,atmos,maxWind]
layer = ipywidgets.Dropdown(options = layers)

# %%
i = ipywidgets.SelectionSlider(options = (range(len(hag.r2))))
var = ipywidgets.Dropdown(options = layer.data_vars)
@ipywidgets.interact(i = i,var = var, layer = layer)
def make_plot(i,var,layer):
    plt.clf
    plt.pcolormesh(layer[var][i])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/5y/htsjngjd7nd_3ddqv2q24ynh0000gq/T/ipykernel_94814/3957249420.py in <module>
#       1 i = ipywidgets.SelectionSlider(options = (range(len(hag.r2))))
# ----> 2 var = ipywidgets.Dropdown(options = layer.data_vars)
#       3 @ipywidgets.interact(i = i,var = var, layer = layer)
#       4 def make_plot(i,var,layer):
#       5     plt.clf
#
# AttributeError: 'Dropdown' object has no attribute 'data_vars'
